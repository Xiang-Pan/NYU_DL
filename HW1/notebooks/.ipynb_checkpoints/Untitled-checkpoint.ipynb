# %% [markdown]
# # Activation

# %%
import torch.nn as nn

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## ReLU

# %%
x = np.linspace(-10, 10, 1000)
y = np.maximum(0, x)
dy = 1

plt.figure(figsize=(10, 5))
plt.plot(x, y)
plt.legend(['Relu'])
plt.show()
